# %%
#load "../utils.fsx"
open Utils
// convert to 2d array
let input = GetData 7 |> Split("\n") |> Array.map (fun x -> x.ToCharArray() |> Array.map string)
input
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><div class="dni-plaintext"><pre>[ ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., . ... (121 more) ]</pre></div></td></tr><tr><td>1</td><td><div class="dni-plaintext"><pre>[ ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., . ... (121 more) ]</pre></div></td></tr><tr><td>2</td><td><div class="dni-plaintext"><pre>[ ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., . ... (121 more) ]</pre></div></td></tr><tr><td>3</td><td><div class="dni-plaintext"><pre>[ ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., . ... (121 more) ]</pre></div></td></tr><tr><td>4</td><td><div class="dni-plaintext"><pre>[ ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., . ... (121 more) ]</pre></div></td></tr><tr><td>5</td><td><div class="dni-plaintext"><pre>[ ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., ., . ... (121 more) ]</pre></div></td></tr><tr><td>6</td><td><div class="d
# ...

# %%
let mutable splitsCount = 0
// Find S in the 2d array
let startingIndex : int = input[0] |> Array.findIndex (fun x -> x = "S")

for row in input do
    let splitters = row |> Array.indexed |> Array.filter (fun (_, x) -> x = "^") |> Array.map fst
    printf "%A" splitters
    // for splitIndex in splitters do
        
    //     row 


    ()
# Out:
# [||][||][|70|][||][|69; 71|][||][|68; 72|][||][|67; 69; 73|][||][|66; 72; 74|][||][|65; 67; 69; 73; 75|][||][|64; 66; 68; 70; 72; 74; 76|][||][|63; 65; 69; 71; 73; 75; 77|][||][|62; 64; 66; 68; 70; 74; 76; 78|][||][|61; 63; 65; 67; 69; 75; 79|][||][|60; 64; 68; 70; 74; 76; 78; 80|][||][|59; 67; 71; 73; 77; 79; 81|][||][|58; 60; 62; 68; 70; 72; 76; 78; 82|][||][|57; 59; 61; 63; 69; 71; 73; 75; 77; 83|][||][|56; 58; 60; 62; 64; 66; 68; 72; 74; 78; 82; 84|][||][|55; 57; 63; 65; 67; 71; 73; 79; 81; 83; 85|][||][|54; 56; 60; 62; 64; 68; 70; 72; 76; 78; 80; 82; 86|][||][|53; 55; 57; 63; 69; 75; 77; 79; 81; 85; 87|][||][|52; 58; 66; 68; 70; 72; 74; 76; 78; 80; 84; 86; 88|][||][|51; 53; 55; 61; 67; 69; 71; 73; 75; 77; 79; 81; 83; 87; 89|][||][|50; 54; 56; 58; 62; 66; 68; 70; 72; 74; 76; 78; 80; 84; 86; 90|][||][|49; 51; 55; 57; 59; 63; 65; 67; 69; 75; 77; 79; 83; 89; 91|][||][|48; 50; 52; 62; 64; 66; 68; 76; 78; 80; 82; 84; 86; 88; 90; 92|][||][|47; 49; 51; 53; 55; 57; 59; 61; 63; 65; 67; 69
# ...
