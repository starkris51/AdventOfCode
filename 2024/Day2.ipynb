# %% [markdown]
# Load some input stuff

# %%
#load "../utils.fsx"
open Utils
let input: string[] = GetData 2 |> GetLines

# %%
// The levels are either all increasing or all decreasing.
// Any two adjacent levels differ by at least one and at most three.
// In the example above, the reports can be found safe or unsafe by checking those rules:

// 7 6 4 2 1: Safe because the levels are all decreasing by 1 or 2.
// 1 2 7 8 9: Unsafe because 2 7 is an increase of 5.
// 9 7 6 2 1: Unsafe because 6 2 is a decrease of 4.
// 1 3 2 4 5: Unsafe because 1 3 is increasing but 3 2 is decreasing.
// 8 6 4 4 1: Unsafe because 4 4 is neither an increase or a decrease.
// 1 3 6 7 9: Safe because the levels are all increasing by 1, 2, or 3.

let isSafe (report: string): bool =
    let levels = Split " " report |> Array.map int
    let diffs =
        levels
        |> Array.pairwise
        |> Array.map (fun (a, b) -> a - b)

    let magnitudeOk =
        diffs
        |> Array.forall (fun d -> d <> 0 && abs d <= 3 && abs d >= 1)
    
    let directionOk =
        (diffs |> Array.forall (fun d -> d > 0))
        || (diffs |> Array.forall (fun d -> d < 0))

    magnitudeOk && directionOk

input |> Array.filter isSafe |> Array.length
# Out:
# <div class="dni-plaintext"><pre>299</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
